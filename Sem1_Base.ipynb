# %% [markdown]
# # Семинар 1: Введение в Python

# %% [markdown]
# ## Организационные вопросы

# %% [markdown]
# ### Внеаудиторное общение

# %% [markdown]
# **Преподаватель:** Бурова Маргарита Борисовна

# %% [markdown]
# * почта: mbburova@gmail.com
# * 89264931203
# * страница курса: http://wiki.cs.hse.ru/Python_для_ОП_%22Психология%22_2021/2022
# * чаты групп в телеграме

# %% [markdown]
# ### Формула оценки

# %% [markdown]
# $ 0.2 \cdot ДЗ 1 + 0.2 \cdot ДЗ 2 + 0.1 \cdot Онлайн + 0.25 \cdot СР + 0.25 \cdot КР $

# %% [markdown]
# * **ДЗ1 и ДЗ2** - Индивидуальные ДЗ
# > Необходимо выполнить 10 критериев, за каждый из критериев ставится 0, 0.5 или 1. Оценка не округляется
# * **Онлайн** - Оценка, полученная за онлайн-курс
# > Процент выполненных заданий, деленный на 10. Оценка не округляется
# * **СР** - Среднее арифметическое по четырем самостоятельным, которые будут проведены на семинарах
# > Самостоятельные в формате компьютерного тестирования, примерно 20-25 минут
# * **КР** - Контрольная работа в формате, соответствующем спецификации НОК, состоящий из тестовых вопросов и задач

# %% [markdown]
# ### Где мы будем работать?
#
# Jupyter Notebook - интерактивная среда для запуска программного кода в браузере. Удобный инструмент для анализа данных, который используется многими специалистами по data science.
#
# ![](https://media.giphy.com/media/5Zesu5VPNGJlm/giphy.gif)

# %% [markdown]
# ###  Меньше текста, больше кода
#
# **Напутствие**:
# - *главное, не бояться пробовать писать код*
# - *каким бы неправильным он ни казался*
# - *скорее всего, ничего такого, что не починится, в рамках Jupyter Notebook вы сделать не сможете*
#
# **Краткая инструкция на все случаи жизни**:
# - Как создать новую ячейку?
#
# > Просто нажать кнопку `+` (*insert cell below*).
#
# - Как запустить код в ячейке?
#
# > Выделить ячейку и нажать кнопку `Run` или `Ctrl + Enter` *(см. Help - Keyboard Shortcuts)*.
#
# - Как понять, что код успешно выполнен?
#
# > Под ячейкой не появились сообщения об ошибках + поле `In []` слева от ячейки содержит число, а не символ `*`.
#
# - Что делать, если код не хочет успешно выполняться, поле слева выглядит вот так `In [*]` и вообще всё зависло аааа помогите
# <img src="https://pp.userapi.com/c543103/v543103112/326eb/UnK2PZuGroQ.jpg" alt="Drawing" style="width: 200px;"/>
#
# > Для прерывания выполнения кода можно попробовать нажать кнопку `■` (*interrupt the kernel*) в панели наверху, либо перезапустить весь проект, нажав соседнюю кнопку (*restart the kernel*).

# %%
2+10
# Out:
# 12

# %% [markdown]
# ## План на сегодня
#
# * Функции и вывод данных
# * Основные типы данных : число, текст, логические переменные
# * Действия с основными типами данных
# * Переменные

# %% [markdown]
# ## Функции и вывод на экран
#
# В дальнейшем вы часто будете использовать _функции_ из Python или из специализированных Python-модулей.
#
# _Функция_ -- это какой-то скрытый от вас программный код, который можно применять для решения конкретной задачи.
#
# Например, познакомимся с функцией `print`:
# - нужна для того, чтобы выводить на экран текст / числа / что угодно ещё
# - формат вызова: `print(<первое, что хотите вывести на экран>, <второе, что хотите вывести на экран>, ...)`
#
# То, что перечисляется внутри скобок и разделяется запятыми, называется *аргументами* или _входами_ функции

# %% [markdown]
# <img src="https://i.ibb.co/12sSpRd/Untitled-Frame-1-11.jpg" alt="Drawing" style="width: 800px;"/>

# %%
print(67+87)
print(42+146)
# Out:
# 154
# 188

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Попробуем вывести результат сложения чисел 42 и 146:

# %%
print(42+146)
# всё, что пишется за знаком #, воспринимается как комментарий и не выполняется в рамках программы
# Out:
# 188

# %% [markdown]
# ## Типы данных: Целые числа - INT (INTEGER)

# %% [markdown]
# Python сам понимает, какой тип у данных. Однако, можно так же и запросить у него данную информацию

# %%
print(type(5))
# Out:
# <class 'int'>

# %% [markdown]
# Разумеется, в python представлены все возможные арифметические операции:

# %%
# сложение
print(4 + 2)
# вычитание
print(4 - 2)
# Out:
# 6
# 2

# %%
# умножение
print(4 * 2)
# деление
print(4 / 2)
# взятие остатка от деления
print(3 % 2)
# Out:
# 8
# 2.0
# 1

# %%
# возведение в степень
print(3 ** 2)
# взятие корня aka возведение в дробную степень
print(3 ** (1 / 2))
# Out:
# 9
# 1.7320508075688772

# %% [markdown]
# Заметим, что здесь у нас в ответах получились не только целые числа, но также дроби.

# %% [markdown]
# ## Типы данных: Вещественные числа - FLOAT

# %%
type(1.5)
# Out:
# float

# %% [markdown]
# На что обратить внимание:
# - числа с десятичной частью, например, $1.43$, в отличие от Excel, в Python пишутся не через запятую `,`, а через точку `.`.
#
# Почувствуйте разницу:

# %%
print(2,6 / 2)  # печатает два числа
print(2, 6 / 2)  # и так тоже два числа, пробел в данном случае неважен
print(2.6 / 2)  # печатает одно число
# Out:
# 2 3.0
# 2 3.0
# 1.3

# %% [markdown]
# Также не стоит путать целочисленное и вещественное деление:

# %%
print(9 / 2)  # печатает ожидаемый дробный результат
print(9 // 2)  # целочисленное деление
print(9 % 2)  # остаток от (целочисленного) отделения
# Out:
# 4.5
# 4
# 1

# %% [markdown]
# Иногда результаты могут быть довольно неожиданные. Может показаться, что python совершенно не умеет считать:

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004

# %% [markdown]
# Еще результат может выводиться в довольно странном формате:

# %%
1.543**1000
# Out:
# 2.3223413936165768e+188

# %% [markdown]
# Такая запись расшифровывается следующим образом:

# %% [markdown]
# $ n \cdot e+188 = n \cdot 10^{188} $

# %% [markdown]
# ## Типы данных: Строки (текст) - STR (STRING)

# %% [markdown]
# С помощью `print` можно печатать не только числа. Например, текст:
# - текстовая строка в питоне -- это любое выражение, заключённое в двойные `"` или одинарные `'` кавычки
# - с точки зрения пользователя ничем не отличается от привычного текста
#
# Например:

# %%
print('Моё имя:')
# Out:
# Моё имя:

# %%
type('Маргарита')
# Out:
# str

# %%
print('Первая'+'пара')
# Out:
# Перваяпара

# %%
print('У меня '+ 'проблема'*20)
# Out:
# У меня проблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблемапроблема

# %% [markdown]
# Ещё строки можно
# - складывать
# - умножать на число
# - см. встроенные методы класса `str`
#
# **lifehack**: *если написать `str.` и нажать клавишу `Tab`, появится список доступных для строк методов*.

# %%
print('how')
print('how' + ' ' + 'are')
print('how' * 3)
print(' are' * 2 + 'you?')
# Out:
# how
# how are
# howhowhow
#  are areyou?

# %% [markdown]
# На что обратить внимание:
# - выражение `1` это число
# - выражение `'1'` это строка
#
# Почувствуйте разницу:

# %%
print(1 + 2)  # печатает число
print('1' + '2')  # печатает результат склеивания строк
print(str(1) + str(2))  # функция str преобразует аргумент в строку
# Out:
# 3
# 12
# 12

# %% [markdown]
# ## Типы данных: Логические переменные - boolean

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
print(type('True'))
# Out:
# <class 'str'>

# %%
print(34 == 30+4)
# Out:
# True

# %%
print(35 == 30-5)
# Out:
# False

# %% [markdown]
# ## Ошибки в Python и что с ними делать
#
# Иногда написанный код не работает. Так бывает. Это не страшно.
#
# Например, я хочу вывести на экран текст следующего вида:
# ```
# День недели: суббота.
# Моё имя: Маргарита
# Мой возраст: 28
# ```
#
# Я написала свой код в ячейке ниже.
#
# Выполните следующую ячейку (казалось бы, что может пойти не так?):

# %%
print('День недели: суббота.')
print('Моё имя: ' + 'Маргарита')
print('Мой возраст: ' + '28')
# Out:
# День недели: суббота.
# Моё имя: Маргарита
# Мой возраст: 28

# %% [markdown]
# ## Переменные

# %% [markdown]
# В Python мы можем записывать в переменные какие-либо значения (или наборы значений):

# %%
number = 99
my_name = 'Маргарита'

# %%
print(number)
print(my_name)
# Out:
# 99
# Маргарита

# %% [markdown]
# Если мы будем реализовывать какие-то действия с переменными, то они будут осуществляться со значениями, которые записаны в эти переменные:

# %%
print(number*my_name)
# Out:
# МаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргаритаМаргарита
